# %%
from datetime import datetime
from synoptic.services import stations_timeseries
# Out:
#   ╭─SynopticPy:HELP────────────────────────────────────────────────────────╮
#   │                                                                        │
#   │ A valid Synoptic token is required to use SynopticPy.                  │
#   │                                                                        │
#   │ You can sign up for an open-access account or view your account at     │
#   │ https://customer.synopticdata.com/                                     │
#   │                                                                        │
#   ├┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┤
#   │                                                                        │
#   │ To use your token with SynopticPy, do one of the following:            │
#   │                                                                        │
#   │  1) Set the environment variable SYNOPTIC_TOKEN with your token.       │
#   │                                                                        │
#   │  2) Configure your token in the ~/.config/SynopticPy/config.toml file  │
#   │     by running the command `synoptic.configure(token="YourTokenHere")` │
#   │                                                                        │
#   │  3) Specify the `token="YourTokenHere"` argument in each requests.     │
#   │                                                                        │
#   ╰────────────────────────────────────────────────────────────────────────╯
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datetime import datetime
# ----> 2 from synoptic.services import stations_timeseries
#
# ImportError: cannot import name 'stations_timeseries' from 'synoptic.services' (/bsuhome/julialober/miniforge3/envs/coherence_v2/lib/python3.11/site-packages/synoptic/services.py)

# %%
TOKEN = '4f9449f2a4aa4619866837a0c079bfe2'

# %%
my_stations = ["REY", "HDP", "IFF"] 

df = stations_timeseries(
    stid=my_stations,
    vars=["wind_speed", "wind_direction", "wind_gust"],
    start=datetime(2026, 1, 1),
    end=datetime(2026, 1, 5)
)
